# %% [markdown]
# # Hours of Sunshine

# %%
# !pip install vega_datasets

# %%
import pandas as pd
import altair as alt
import numpy as np
from vega_datasets import data

# %%
df = pd.read_csv("sunshine.csv")
df
# Out:
#        city         lon        lat month  monthnum  sunshine
# 0   Chicago  -87.623177  41.881832   Jan         0       135
# 1   Chicago  -87.623177  41.881832   Feb         1       136
# 2   Chicago  -87.623177  41.881832   Mar         2       187
# 3   Chicago  -87.623177  41.881832   Apr         3       215
# 4   Chicago  -87.623177  41.881832   May         4       281
# ..      ...         ...        ...   ...       ...       ...
# 67  Seattle -122.335167  47.608013   Aug         7       281
# 68  Seattle -122.335167  47.608013   Sep         8       221
# 69  Seattle -122.335167  47.608013   Oct         9       142
# 70  Seattle -122.335167  47.608013   Nov        10        72
# 71  Seattle -122.335167  47.608013   Dec        11        52
#
# [72 rows x 6 columns]

# %%
# Subset the data to only include the month of April
df_apr = df[df["month"] == "Apr"]
df_apr
# Out:
#              city         lon        lat month  monthnum  sunshine
# 3         Chicago  -87.623177  41.881832   Apr         3       215
# 15        Houston  -95.358421  29.749907   Apr         3       212
# 27          Miami  -80.191788  25.761681   Apr         3       275
# 39       New York  -73.935242  40.730610   Apr         3       237
# 51  San Francisco -122.446747  37.733795   Apr         3       281
# 63        Seattle -122.335167  47.608013   Apr         3       207

# %%
states = alt.topo_feature(data.us_10m.url, "states")
background = alt.Chart(states).mark_geoshape(
    fill="lightgray",
    stroke="white"
).project("albersUsa").properties(
    width=500,
    height=400
)

cities = alt.Chart(df_apr).mark_circle(
    size=200,  # Fixed size
    opacity=0.7,
    stroke="black",
    strokeWidth=1
).encode(
    longitude='lon:Q',
    latitude='lat:Q',
    color=alt.Color('sunshine:Q', scale=alt.Scale(scheme='yelloworange'), title="Sunshine Hours"),
    tooltip=['city:N', 'sunshine:Q']
).project("albersUsa").properties(
    width=500,
    height=400
)

background + cities
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# Cell In[25], line 18
#       1 states = alt.topo_feature(data.us_10m.url, "states")
#       2 background = alt.Chart(states).mark_geoshape(
#       3     fill="lightgray",
#       4     stroke="white"
#    (...)      7     height=400
#       8 )
#      10 cities = alt.Chart(df_apr).mark_circle(
#      11     size=200,  # Fixed size
#      12     opacity=0.7,
#      13     stroke="black",
#      14     strokeWidth=1
#      15 ).encode(
#      16     longitude='lon:Q',
#      17     latitude='lat:Q',
# ---> 18     color=alt.Color('sunshine:Q', scale=alt.Scale(scheme='yelloworange'), title="Sunshine Hours"),
#      19     tooltip=['city:N', 'sunshine:Q']
#      20 ).project("albersUsa").properties(
#      21     width=500,
#      22     height=400
#      23 )
#      25 background + cities
#
# ...
