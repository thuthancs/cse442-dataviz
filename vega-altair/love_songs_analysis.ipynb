# %%
# !pip install pandas
# !pip install "altair[all]"
# Out:
# Requirement already satisfied: pandas in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: altair[all] in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (6.0.0)
# Requirement already satisfied: jinja2 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (2.14.0)
# Requirement already satisfied: packaging in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (25.0)
# Requirement already satisfied: typing-extensions>=4.12.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (4.15.0)
# Requirement already satisfied: altair-tiles>=0.3.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (0.4.0)
# Requirement already satisfied: anywidget>=0.9.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (0.9.21)
# Requirement already satisfied: numpy in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (2.4.0)
# Requirement already satisfied: pandas>=1.1.3 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (2.3.3)
# Requirement already satisfied: pyarrow>=11 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (22.0.0)
# Requirement already satisfied: vegafusion>=2.0.3 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (2.0.3)
# Requirement already satisfied: vl-convert-python>=1.8.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair[all]) (1.9.0)
# Requirement already satisfied: mercantile in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair-tiles>=0.3.0->altair[all]) (1.2.1)
# Requirement already satisfied: xyzservices in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from altair-tiles>=0.3.0->altair[all]) (2025.11.0)
# Requirement already satisfied: ipywidgets>=7.6.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from anywidget>=0.9.0->altair[all]) (8.1.8)
# Requirement already satisfied: psygnal>=0.8.1 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from anywidget>=0.9.0->altair[all]) (0.15.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair[all]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair[all]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair[all]) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pandas>=1.1.3->altair[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pandas>=1.1.3->altair[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pandas>=1.1.3->altair[all]) (2025.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.3->altair[all]) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget>=0.9.0->altair[all]) (0.2.3)
# Requirement already satisfied: arro3-core in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from vegafusion>=2.0.3->altair[all]) (0.6.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from jinja2->altair[all]) (3.0.3)
# Requirement already satisfied: click>=3.0 in /Users/thananhthu/cse442-dataviz/.venv/lib/python3.12/site-packages (from mercantile->altair-tiles>=0.3.0->altair[all]) (8.3.1)

# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv("../data/pudding_love_songs_2023.csv")
df.head()
# Out:
#           song_title     pipe_delimited_artist_list love_song_category  \
# 0         Yakety Yak                   The Coasters                NaN
# 1      Splish Splash                    Bobby Darin                NaN
# 2               When                    Kalin Twins           Serenade
# 3  Hard Headed Woman  Elvis Presley|The Jordanaires   It's Complicated
# 4           Patricia                    Perez Prado                NaN
#
#    top_10_debut_date_as_decimal  total_weeks_in_top_10
# 0                       1958.59                      1
# 1                       1958.59                      3
# 2                       1958.59                      5
# 3                       1958.59                      2
# 4                       1958.59                      6

# %%
# Preprocess the data by replacing NaN with Uncategorized
df["love_song_category"] = df["love_song_category"].fillna("Uncategorized")
df.head()
# Out:
#           song_title     pipe_delimited_artist_list love_song_category  \
# 0         Yakety Yak                   The Coasters      Uncategorized
# 1      Splish Splash                    Bobby Darin      Uncategorized
# 2               When                    Kalin Twins           Serenade
# 3  Hard Headed Woman  Elvis Presley|The Jordanaires   It's Complicated
# 4           Patricia                    Perez Prado      Uncategorized
#
#    top_10_debut_date_as_decimal  total_weeks_in_top_10
# 0                       1958.59                      1
# 1                       1958.59                      3
# 2                       1958.59                      5
# 3                       1958.59                      2
# 4                       1958.59                      6

# %%
# Count the number of songs that belong to each category and sorted in a decreasing order
num_categories = df["love_song_category"].unique()
count_per_category = df.groupby('love_song_category')['song_title'].count().sort_values(ascending=False).reset_index(name='count')

# Add explanation for each song category (adapted from https://pudding.cool/2024/11/love-songs/)
explanation = {
    "Serenade": "Unmistakably about romantic love and devotion, sung from one person to another",
    "Heartache": "But what happens if you love them, but they just... don’t? Maybe you broke up, or maybe it’s just unrequited",
    "It's Complicated": "The messier side of romance. What about when a relationship isn’t clearly good or bad? Maybe you fight constantly. Maybe they’re unfaithful. But you still try to make it work",
    "Pursuit": "When you love someone, and it might become something more? You just spotted someone, your heart is beating fast, and who KNOWS where this thing might lead?",
    "Sexual Confidence": "Songs that get a little steamy? Think artists like Nicki Minaj and Drake, who dominate this category that's all about getting into bed with someone.",
    "Good Riddance": 'The relationship is clearly over, but the songwriter’s heartbreak has resurrected into... righteous power? They’re not crying, they’re yelling “Good Riddance!”',
    "Love Song for the Self": "Women-pioneered Love Song for the Self is the most modern of all the genres. And while it’s not written to a lover, it’s often written in reaction to romantic rejection.",
    "Uncategorized": "Songs that don't fit anywhere else"
}

# Merge the explanation to the count dataset
explanation_df = pd.DataFrame.from_dict(explanation, orient="index").reset_index()
explanation_df.columns = ["love_song_category", "explanation"]

# %%
count_per_category
# Out:
#        love_song_category  count
# 0           Uncategorized   1798
# 1                Serenade   1042
# 2               Heartache    827
# 3        It's Complicated    484
# 4                 Pursuit    445
# 5       Sexual Confidence    315
# 6           Good Riddance    125
# 7  Love Song for the Self    105

# %%
explanation_df
# Out:
#        love_song_category                                        explanation
# 0                Serenade  Unmistakably about romantic love and devotion,...
# 1               Heartache  But what happens if you love them, but they ju...
# 2        It's Complicated  The messier side of romance. What about when a...
# 3                 Pursuit  When you love someone, and it might become som...
# 4       Sexual Confidence  Songs that get a little steamy? Think artists ...
# 5           Good Riddance  The relationship is clearly over, but the song...
# 6  Love Song for the Self  Women-pioneered Love Song for the Self is the ...
# 7           Uncategorized                 Songs that don't fit anywhere else

# %%
merged_df = pd.merge(count_per_category, explanation_df, on="love_song_category")

# %%
merged_df
# Out:
#        love_song_category  count  \
# 0           Uncategorized   1798
# 1                Serenade   1042
# 2               Heartache    827
# 3        It's Complicated    484
# 4                 Pursuit    445
# 5       Sexual Confidence    315
# 6           Good Riddance    125
# 7  Love Song for the Self    105
#
#                                          explanation
# 0                 Songs that don't fit anywhere else
# 1  Unmistakably about romantic love and devotion,...
# 2  But what happens if you love them, but they ju...
# 3  The messier side of romance. What about when a...
# 4  When you love someone, and it might become som...
# 5  Songs that get a little steamy? Think artists ...
# 6  The relationship is clearly over, but the song...
# 7  Women-pioneered Love Song for the Self is the ...

# %%
select = alt.selection_point(name="select", on="click")
highlight = alt.selection_point(name="highlight", on="pointerover", empty=False)

stroke_width = (
    alt.when(select).then(alt.value(2, empty=False))
    .when(highlight).then(alt.value(1))
    .otherwise(alt.value(0))
)

alt.Chart(merged_df).mark_bar(
    fill="#E78483", stroke="black", cursor="pointer"
).encode(
    alt.X('count').title("Number of Love Songs"),
    alt.Y("love_song_category").title("Category").sort('-x'),
    fillOpacity=alt.when(select).then(alt.value(1)).otherwise(alt.value(0.3)),
    strokeWidth=stroke_width,
).properties(
    width=800,
    height=300
).configure_scale(bandPaddingInner=0.2).add_params(select, highlight)
# Out:
# alt.Chart(...)
